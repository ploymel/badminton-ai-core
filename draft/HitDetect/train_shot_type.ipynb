# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Get hit type

# %%
import json

with open('./hit_types.json', 'r') as file:
    hit_types = json.load(file)

hit_types
# Out:
# ['clear',
#  'defensive shot',
#  'drive',
#  'drop',
#  'lob',
#  'long service',
#  'net shot',
#  'push/rush',
#  'short service',
#  'smash']

# %%
import torch
from torch.utils.data import Dataset
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import pandas as pd
import torch
from torch.utils.data import Dataset
import numpy as np
from torch.utils.data import DataLoader
import os
import random

'''
human keypoints: 17*2
court keypoints: 6*2
net keypoints:   4*2
ball keypoints:  1*2
total keypoints: 28*2

'''




class HitTypeDataset(Dataset):
    def __init__(self, dataset_folder,num_consecutive_frames,normalization=True):
        self.dataset=[]
        self.positive=0
        self.negative=0
        # 遍历文件夹及其子文件夹，找到所有的CSV文件路径
        cnt=0
        for root, dirs, files in os.walk(dataset_folder):
            for file in files:
                if file.endswith(".csv"):
                    # 定义处理函数
                    data_path=os.path.join(root, file)
                    print(data_path)

                    try:
                      df= pd.read_csv(data_path, converters={"ball": eval,"top":eval,"bottom":eval,"court":eval,"net":eval})
                    except:
                      print('Error! cannot process: ', data_path)
                      continue

                    rows = len(df)
                    remainder = rows % 30
                    if remainder > 0:
                        num_to_pad = 30 - remainder
                    else:
                        num_to_pad = 0

                    if num_to_pad > 0:
                        last_row = df.iloc[-1]
                        padding_data = np.tile(last_row.values, (num_to_pad, 1))
                        padded_df = pd.DataFrame(padding_data, columns=df.columns)
                        df = pd.concat([df, padded_df], axis=0)
                        df = df.reset_index(drop=True)

                    small_dataset =df

                    for i in range(len(small_dataset)):
                        if i%num_consecutive_frames!=0:
                            continue
                        if i>=len(small_dataset)-num_consecutive_frames:
                            break
                        oridata=small_dataset.loc[i:i+num_consecutive_frames-1,:].copy()
                        oridata=oridata.reset_index(drop=True)
                        data=[]

                        target1=None

                        for index,row in oridata.iterrows():
                            pos=np.array(row['type'])
                            if str(pos) in ["defensive shot", "drive"]:
                            # if str(pos) in hit_types:
                                if target1 is None:
                                    target1=1
                                    self.positive+=1

                            top=np.array(row['top']).reshape(-1,2)
                            bottom=np.array(row['bottom']).reshape(-1,2)
                            court=np.array(row['court']).reshape(-1,2)
                            net=np.array(row['net']).reshape(-1,2)
                            ball=np.array(row['ball']).reshape(-1,2)

                            frame_data = np.concatenate((top, bottom, court, net, ball), axis=0)

                            if normalization:
                                frame_data[:,0]/=1920
                                frame_data[:,1]/=1080
                            data.append(frame_data.reshape(1,-1))
                        data=np.array(data)
                        if target1 is None:
                            if self.negative>self.positive:
                                continue
                            target1=0
                            self.negative+=1
                        self.dataset.append((data.reshape(-1),target1))


    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, index):
        # 假设每个样本是一个元组 (input, target)
        sample = self.dataset[index]
        input_data = sample[0]
        target1 = sample[1]

        # 转换为Tensor对象
        input_tensor = torch.tensor(input_data)
        target1_tensor = torch.tensor(target1)

        return input_tensor, target1_tensor


num_consecutive_frames=30
batch_size=30
shuffle=True
normalization=True

TrainDataset=HitTypeDataset("./train",num_consecutive_frames,normalization)
ValidDataset=HitTypeDataset("./valid",num_consecutive_frames,normalization)
# Out:
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-24.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-18.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-25.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-38.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-39.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-11.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-9.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-8.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-14.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-24.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-26.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-33.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-1.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-37.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-23.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-22.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-6.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_2-35.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-2.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-28.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-14.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-29.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-11.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-4.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-5.csv
# ./train/Ratchanok_INTANON_WANG_Zhi_Yi_Malaysia_Open_2022_SemiFinals/rally_1-7.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-23.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-35.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-8.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-20.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-24.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-30.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-19.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-31.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-25.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-33.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-38.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-9.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-12.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-16.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-29.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-15.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-14.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-28.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-18.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-30.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-24.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-2.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-32.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-27.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-33.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-1.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-23.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-6.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_2-34.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-17.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-2.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-16.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-1.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-15.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-29.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-5.csv
# ./train/Carolina_MARIN_Akane_YAMAGUCHI_French_Open_2022_SemiFinals/rally_1-10.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-33.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-27.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-36.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-22.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-9.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-23.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-37.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-26.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-32.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-24.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-30.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-35.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-8.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-9.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-34.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-20.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-31.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-25.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-19.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-35.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-24.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-30.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-19.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-25.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-34.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-36.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-22.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-33.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-27.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-26.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-32.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-23.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-37.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-10.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-11.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-9.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-13.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-12.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-8.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-16.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-17.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-41.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-29.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-14.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-40.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-3.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-25.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-19.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-18.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-30.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-24.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-2.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-26.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-27.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-1.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-5.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-23.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-22.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-4.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-6.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-20.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-21.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_2-7.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-17.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-2.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-3.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-16.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-1.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-13.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-39.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-11.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-28.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-3.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-1.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-15.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-2.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-29.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-10.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-38.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-14.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-28.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-11.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-6.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-4.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-5.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-7.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-29.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-15.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-17.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-12.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-5.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-7.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-6.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-4.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_1-13.csv
# ./train/HE_Bing_Jiao_Carolina_MARIN_French_Open_2022_Final/rally_3-16.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-33.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-27.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-36.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-22.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-37.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-32.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-18.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-24.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-30.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-8.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-9.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-34.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-20.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-21.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-35.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-24.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-30.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-20.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-36.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-33.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-32.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-23.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-10.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-11.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-40.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-9.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-13.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-12.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-8.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-16.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-17.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-29.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-14.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-40.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-31.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-19.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-18.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-30.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-24.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-2.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-26.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-27.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-1.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-37.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-22.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-36.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-4.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-6.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-20.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-34.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-35.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_2-21.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-12.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-17.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-2.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-3.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-1.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-39.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-28.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-2.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-29.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-10.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-38.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-14.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-28.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-11.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-39.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-7.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-10.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-17.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-12.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-5.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-6.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_1-13.csv
# ./train/LI_Shi_Feng_Kodai_NARAOKAGR_Thailand_Open_2022_Semi_finals/rally_3-16.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-36.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-22.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-23.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-37.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-21.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-35.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-8.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-9.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-34.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-20.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-24.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-30.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-18.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-19.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-25.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-33.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-27.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-26.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-32.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-11.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-13.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-8.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-16.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-17.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-15.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-28.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-31.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-19.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-18.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-30.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-24.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-2.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-32.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-26.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-1.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-5.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-23.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-22.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-36.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-6.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-34.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-35.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-21.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_2-7.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-17.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-2.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-3.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-16.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-28.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-14.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-1.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-15.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-11.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-4.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-10.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-6.csv
# ./train/EAST_VENTURES_Indonesia_Open_2022_Zhao_Jun_Peng_PRANNOY_H__S__Semifinals/rally_1-13.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-36.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-22.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-21.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-8.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-34.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-20.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-24.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-30.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-18.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-31.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-25.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-32.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-11.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-9.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-12.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-8.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-16.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-17.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-15.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-19.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-18.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-30.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-32.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-27.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-33.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-1.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-22.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-6.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_2-21.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-17.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-2.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-15.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-29.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-12.csv
# ./train/CHEN_Yu_Fei_HE_Bing_Jiao_DAIHATSU_Indonesia_Masters_2022_Semifinals/rally_1-7.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-36.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-22.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-23.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-37.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-8.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-9.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-34.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-20.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-18.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-19.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-31.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-25.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-27.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-26.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-32.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-10.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-38.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-39.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-11.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-9.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-12.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-8.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-16.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-17.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-29.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-15.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-14.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-3.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-25.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-31.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-18.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-30.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-24.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-2.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-32.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-27.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-33.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-37.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-23.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-36.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-6.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-20.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-34.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_2-7.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-17.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-16.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-28.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-14.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-15.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-11.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-4.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-5.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-10.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-12.csv
# ./train/AN_Se_Young_Pornpawee_CHOCHUWONG_Korea_Open_Badminton_Championships_2022_Finals/rally_1-13.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-8.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-18.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-30.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-8.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-20.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-19.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-21.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-30.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-19.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-22.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-33.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-26.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-13.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-12.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-17.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-29.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-15.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-14.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-28.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-25.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-19.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-18.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-26.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-27.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-1.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-5.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-22.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-6.csv
# Error! cannot process:  ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-6.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-20.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-34.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_2-21.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-3.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-1.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-11.csv
# Error! cannot process:  ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-11.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-3.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-14.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-29.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-14.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-28.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-4.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_1-5.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-7.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-15.csv
# ./train/Supanida_KATETHONG_PUSARLA_V__Sindhu_India_Open_2022_SemiFinals/rally_3-17.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-22.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-9.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-20.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-30.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-19.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-31.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-27.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-26.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-10.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-9.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-12.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-14.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-3.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-31.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-19.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-30.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-32.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-26.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-27.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-1.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-5.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-23.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-22.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-4.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-20.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-34.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_2-7.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-17.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-2.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-3.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-16.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-1.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-15.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-11.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-4.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-5.csv
# ./train/Akane_YAMAGUCHI_CHEN_Yu_Fei_England_Open_2022_Semi_finals/rally_1-10.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-21.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-8.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-9.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-20.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-24.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-30.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-18.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-19.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-25.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-13.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-12.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-29.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-15.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-28.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-3.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-25.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-19.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-18.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-24.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-26.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-27.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-5.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-23.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-22.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-4.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_2-6.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-17.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-2.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-3.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-14.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-1.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-4.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-10.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-12.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-6.csv
# ./train/Viktor_AXELSEN_ZHAO_Jun_Peng_Indonesia_Open_2022_Final/rally_1-13.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-22.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-8.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-9.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-20.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-31.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-26.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-17.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-14.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-3.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-18.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-2.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-33.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-4.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-6.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-20.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-34.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_2-21.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-17.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-2.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-16.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-14.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-29.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-5.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-10.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-12.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-7.csv
# ./train/Viktor_AXELSEN_Lakshya_SEN_YONEX_All_England_Open_2022_Finals/rally_1-13.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-27.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-9.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-8.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-23.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-32.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-18.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-24.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-30.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-8.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-34.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-20.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-21.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-35.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-24.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-30.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-18.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-19.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-25.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-34.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-20.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-36.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-33.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-26.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_1-32.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-37.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-11.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-9.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-12.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-16.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-29.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-15.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-14.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_3-40.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-3.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-19.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-18.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-24.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-32.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-26.csv
# ./train/Lakshya_SEN_LEE_Zii_Jia_All_England_Open_2022_SemiFinals/rally_2-33.csv
# ...
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-31.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-25.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-19.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-30.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-18.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-19.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-34.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-22.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-33.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-27.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-26.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-32.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-23.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-10.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-38.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-40.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-9.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-42.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-13.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-8.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-16.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-17.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-28.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-25.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-31.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-18.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-30.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-24.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-2.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-32.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-1.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-37.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-36.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-4.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-20.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-35.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_2-7.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-12.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-17.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-2.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-3.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-16.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-1.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-13.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-11.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-28.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-3.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-14.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-1.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-15.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-2.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-29.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-10.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-14.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-28.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-11.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-4.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-5.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-7.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-38.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-10.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-17.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-12.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-5.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_1-6.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-4.csv
# ./train/Busanan_ONGBAMRUNGPHAN_Supanida_KATETHONG_India_Open_2022_Finals/rally_3-16.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-22.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-23.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-37.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-35.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-8.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-9.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-20.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-24.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-30.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-18.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-19.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-25.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-33.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-27.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-32.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-10.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-11.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-40.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-9.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-13.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-12.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-8.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-16.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-17.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-29.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-28.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-30.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-24.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-32.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-27.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-1.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-23.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-22.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-4.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-21.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_2-7.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-17.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-2.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-3.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-16.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-14.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-1.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-29.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-11.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-4.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-38.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-12.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-7.csv
# ./valid/Akane_YAMAGUCHI_AN_Se_Young_BWF_World_Championships_2022_Semi_finals/rally_1-6.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-36.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-23.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-26.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-32.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-18.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-30.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-35.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-8.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-9.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-34.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-31.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-25.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-19.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-31.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-20.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-22.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-33.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-27.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-23.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-10.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-38.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-39.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-9.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-12.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-8.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-29.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-28.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-3.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-25.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-31.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-19.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-24.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-2.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-26.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-1.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-37.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-23.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-22.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-36.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-4.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-6.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-20.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-35.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-21.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-7.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-12.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-17.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-2.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-3.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-28.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-3.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-1.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-2.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-10.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-14.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-28.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-11.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-6.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-4.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-40.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-29.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-15.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-12.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_2-42.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-6.csv
# ./valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_3-4.csv

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ShotTypeModel(nn.Module):
    def __init__(self, feature_dim, num_consecutive_frames):
        super(ShotTypeModel, self).__init__()
        self.num_consecutive_frames = num_consecutive_frames
        self.feature_dim = feature_dim

        self.gru1 = nn.GRU(feature_dim // num_consecutive_frames, 64, bidirectional=True, batch_first=True)
        self.gru2 = nn.GRU(128, 64, bidirectional=True, batch_first=True)
        self.global_maxpool = nn.MaxPool1d(num_consecutive_frames)
        self.dense = nn.Linear(128, 1)  # Output layer for binary classification

    def forward(self, x):
        batch_size = x.shape[0]
        x = x.float()
        x = x.view(batch_size, self.num_consecutive_frames, self.feature_dim // self.num_consecutive_frames)
        x, _ = self.gru1(x)
        x, _ = self.gru2(x)
        x = x.transpose(1, 2)
        x = self.global_maxpool(x).squeeze()
        x = self.dense(x)
        return x  # Removed softmax, output is now logits


print(TrainDataset.positive,TrainDataset.negative)
print(ValidDataset.positive,ValidDataset.negative)

feature_dim=90*num_consecutive_frames
train_data_loader = DataLoader(TrainDataset, batch_size=batch_size, shuffle=shuffle, drop_last=True)

valid_data_loader = DataLoader(ValidDataset, batch_size=batch_size, shuffle=shuffle, drop_last=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model=ShotTypeModel(feature_dim,num_consecutive_frames)
criterion = nn.BCEWithLogitsLoss()
model.to(device)
criterion.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 100



train_loss_list = []
valid_loss_list=[]
for epoch in range(num_epochs):
    train_loss_sum=0
    model.train()
    for batch_data in train_data_loader:
        inputs, labels = batch_data
        inputs = inputs.to(device)  # 将输入数据移动到设备上
        labels = labels.to(device).float()  # 将输入数据移动到设备上

        outputs = model(inputs)

        train_loss = criterion(outputs, labels.view(-1, 1))
        train_loss_sum+=train_loss.detach()
        # 反向传播和优化
        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()
        # 执行你的训练或测试操作
    train_loss_list.append(train_loss_sum)


    # 打印训练信息
    if (epoch + 1) % 1== 0:
        print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch + 1, num_epochs,
                                                    train_loss.item()))
    with torch.no_grad():
        true_positives = 0
        total_positives = 0  # Actual positives in the dataset
        for inputs, labels in valid_data_loader:
            inputs = inputs.to(device)  # Move input data to the device
            labels = labels.to(device)
            # Forward pass
            outputs = model(inputs).squeeze()  # Squeeze to ensure output is of shape [batch_size]

            # Applying a threshold to determine predictions
            predictions = outputs > 0.5  # Outputs > 0.0 are classified as 1, else 0
            
            # Count true positives and total actual positives
            true_positives += ((predictions == 1) & (labels == 1)).sum().item()
            total_positives += (labels == 1).sum().item()

        if total_positives > 0:
            positive_accuracy = true_positives / total_positives
            print(f'Accuracy on positive class: {positive_accuracy}')
        else:
            print("No positive instances in the dataset.")
# Out:
# 2529 2530
# 173 172
# Epoch [1/100], Loss: 0.6056
# Accuracy on positive class: 0.5670731707317073
# Epoch [2/100], Loss: 0.5741
# Accuracy on positive class: 0.19631901840490798
# Epoch [3/100], Loss: 0.5412
# Accuracy on positive class: 0.44171779141104295
# Epoch [4/100], Loss: 0.3392
# Accuracy on positive class: 0.6227544910179641
# Epoch [5/100], Loss: 0.4215
# Accuracy on positive class: 0.4817073170731707
# Epoch [6/100], Loss: 0.6545
# Accuracy on positive class: 0.5963855421686747
# Epoch [7/100], Loss: 0.7144
# Accuracy on positive class: 0.5670731707317073
# Epoch [8/100], Loss: 0.3010
# Accuracy on positive class: 0.6727272727272727
# Epoch [9/100], Loss: 0.4993
# Accuracy on positive class: 0.7831325301204819
# Epoch [10/100], Loss: 0.4239
# Accuracy on positive class: 0.41916167664670656
# Epoch [11/100], Loss: 0.4100
# Accuracy on positive class: 0.7212121212121212
# Epoch [12/100], Loss: 0.2762
# Accuracy on positive class: 0.6484848484848484
# Epoch [13/100], Loss: 0.3389
# Accuracy on positive class: 0.7116564417177914
# Epoch [14/100], Loss: 0.3779
# Accuracy on positive class: 0.75
# Epoch [15/100], Loss: 0.4057
# Accuracy on positive class: 0.7305389221556886
# Epoch [16/100], Loss: 0.4067
# Accuracy on positive class: 0.7023809523809523
# Epoch [17/100], Loss: 0.3066
# Accuracy on positive class: 0.8
# Epoch [18/100], Loss: 0.3699
# Accuracy on positive class: 0.8395061728395061
# Epoch [19/100], Loss: 0.4077
# Accuracy on positive class: 0.7423312883435583
# Epoch [20/100], Loss: 0.2138
# Accuracy on positive class: 0.7668711656441718
# Epoch [21/100], Loss: 0.2357
# Accuracy on positive class: 0.8012048192771084
# Epoch [22/100], Loss: 0.2988
# Accuracy on positive class: 0.8353658536585366
# Epoch [23/100], Loss: 0.3631
# Accuracy on positive class: 0.7361963190184049
# Epoch [24/100], Loss: 0.4123
# Accuracy on positive class: 0.8402366863905325
# Epoch [25/100], Loss: 0.3777
# Accuracy on positive class: 0.7365269461077845
# Epoch [26/100], Loss: 0.4803
# Accuracy on positive class: 0.6946107784431138
# Epoch [27/100], Loss: 0.3166
# Accuracy on positive class: 0.7696969696969697
# Epoch [28/100], Loss: 0.3253
# Accuracy on positive class: 0.7440476190476191
# Epoch [29/100], Loss: 0.3884
# Accuracy on positive class: 0.7951807228915663
# Epoch [30/100], Loss: 0.2300
# Accuracy on positive class: 0.8058823529411765
# Epoch [31/100], Loss: 0.3156
# Accuracy on positive class: 0.8012422360248447
# Epoch [32/100], Loss: 0.4407
# Accuracy on positive class: 0.823170731707317
# Epoch [33/100], Loss: 0.4731
# Accuracy on positive class: 0.8363636363636363
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 56
#      53 inputs = inputs.to(device)  # 将输入数据移动到设备上
#      54 labels = labels.to(device).float()  # 将输入数据移动到设备上
# ---> 56 outputs = model(inputs)
#      58 train_loss = criterion(outputs, labels.view(-1, 1))
#      59 train_loss_sum+=train_loss.detach()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[2], line 20, in ShotTypeModel.forward(self, x)
#      18 x = x.float()
#      19 x = x.view(batch_size, self.num_consecutive_frames, self.feature_dim // self.num_consecutive_frames)
# ---> 20 x, _ = self.gru1(x)
#      21 x, _ = self.gru2(x)
#      22 x = x.transpose(1, 2)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/rnn.py:1100, in GRU.forward(self, input, hx)
#    1098 self.check_forward_args(input, hx, batch_sizes)
#    1099 if batch_sizes is None:
# -> 1100     result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
#    1101                      self.dropout, self.training, self.bidirectional, self.batch_first)
#    1102 else:
#    1103     result = _VF.gru(input, batch_sizes, hx, self._flat_weights, self.bias,
#    1104                      self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %%
# 保存整个模型
torch.save(model, './defensive-shot_shot_detect.pth')

# # print(f"best_accuracy={best_accuracy}")
# with torch.no_grad():
#     correct = 0
#     total = 0
#     for inputs, labels in valid_data_loader:
#         inputs = inputs.to(device)  # 将输入数据移动到设备上
#         labels = labels.to(device).float()  # 将标签移动到设备上

#         # 前向传播
#         outputs = model(inputs)

#         y_true=torch.argmax(labels,axis=1)
#         y_pred=torch.argmax(outputs,axis=1)
#         print(y_true)
#         print(y_pred)
#         total+=len(y_true)
#         correct+=(y_true==y_pred).sum().item()


#     print(f'Accuracy on test set: {correct/total}')

# %%
# final_list=[]
# true_list=[]
# data_path="/content/drive/MyDrive/Badminton_Player_Analysis_Project/SoloShuttlePose/draft/HitDataset/valid/Viktor_AXELSEN_Jonatan_CHRISTIE_Malaysia_Open_2022_SemiFinals/rally_1-12.csv"
# df= pd.read_csv(data_path, converters={"ball": eval,"top":eval,"bottom":eval,"court":eval,"net":eval})

# rows = len(df)
# remainder = rows % 12
# if remainder > 0:
#     num_to_pad = 12 - remainder
# else:
#     num_to_pad = 0

# if num_to_pad > 0:
#     last_row = df.iloc[-1]
#     padding_data = np.tile(last_row.values, (num_to_pad, 1))
#     padded_df = pd.DataFrame(padding_data, columns=df.columns)
#     df = pd.concat([df, padded_df], axis=0)
#     df = df.reset_index(drop=True)

# small_dataset =df
# probs_list=[]
# for i in range(len(small_dataset)):

#     if i>=len(small_dataset)-num_consecutive_frames:
#         break


#     oridata=small_dataset.loc[i:i+num_consecutive_frames-1,:].copy()
#     oridata=oridata.reset_index(drop=True)
#     data=[]
#     # print(oridata)
#     if str(oridata.loc[0,'pos'])=='nan':
#             true_list.append(0)
#     elif str(oridata.loc[0,'pos'])=='top':
#             true_list.append(1)
#     elif str(oridata.loc[0,'pos'])=='bottom':
#             true_list.append(2)

#     for index,row in oridata.iterrows():

#         top=np.array(row['top']).reshape(-1,2)
#         bottom=np.array(row['bottom']).reshape(-1,2)
#         court=np.array(row['court']).reshape(-1,2)
#         # net=np.array(row['net']).reshape(-1,2)
#         ball=np.array(row['ball']).reshape(-1,2)

#         frame_data = np.concatenate((top, bottom, court, ball), axis=0)

#         if normalization:
#             # 将 x 坐标从 0 到 1920 映射到 1 到 2
#             frame_data[:,0] /=1920

#             # 将 y 坐标从 0 到 1080 映射到 1 到 2
#             frame_data[:,1] /=1080

#         data.append(frame_data.reshape(1,-1))
#     data=np.array(data).reshape(1,-1)
#     # print(data.shape)
#     # if i%num_consecutive_frames!=0:
#     #     final_list.append(0)
#     #     continue
#     outputs=model(torch.FloatTensor(data).to(device))

#     # print(outputs)
#     pred=torch.argmax(outputs).item()
#     probs=outputs[pred].item()
#     final_list.append(pred)

# print(true_list)
# print(final_list)
